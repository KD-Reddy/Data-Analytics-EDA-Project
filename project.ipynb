# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("STofkids.csv")

# %%
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
print("First 3 rows of the DataFrame:")
df.head(3)
# Out:
# First 3 rows of the DataFrame:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban

# %%
df.tail()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# ...

# %%
print("\nLast 3 rows of the DataFrame:")
df.tail(3)
# Out:
# Last 3 rows of the DataFrame:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710                       Poor Sleep          Urban
# 9711                          Anxiety          Urban

# %%
print("\nInformation about the DataFrame:")
df.info()
# Out:
# Information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
print("\nDescriptive statistics of the DataFrame:")
df.describe()
# Out:
# Descriptive statistics of the DataFrame:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
print("\nData types of each column in the DataFrame:")
print(df.dtypes)
# Out:
# Data types of each column in the DataFrame:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df.shape
# Out:
# (9712, 8)

# %%
df.shape[0]
# Out:
# 9712

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Avg_Daily_Screen_Time_hr', 'Primary_Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Urban_or_Rural'],
#       dtype='object')

# %%
df.values
# Out:
# array([[14, 'Male', 3.99, ..., 0.42, 'Poor Sleep, Eye Strain', 'Urban'],
#        [11, 'Female', 4.61, ..., 0.3, 'Poor Sleep', 'Urban'],
#        [18, 'Female', 3.73, ..., 0.32, 'Poor Sleep', 'Urban'],
#        ...,
#        [16, 'Male', 5.62, ..., 0.39, 'Poor Sleep, Eye Strain, Anxiety',
#         'Rural'],
#        [17, 'Male', 5.6, ..., 0.43, 'Poor Sleep', 'Urban'],
#        [15, 'Female', 6.12, ..., 0.33, 'Anxiety', 'Urban']], dtype=object)

# %%
df['Primary_Device'].unique()
# Out:
# array(['Smartphone', 'Laptop', 'TV', 'Tablet'], dtype=object)

# %%
print("\nMemory usage of each column in the DataFrame:")
print(df.memory_usage())
# Out:
# Memory usage of each column in the DataFrame:
# Index                                  132
# Age                                  77696
# Gender                               77696
# Avg_Daily_Screen_Time_hr             77696
# Primary_Device                       77696
# Exceeded_Recommended_Limit            9712
# Educational_to_Recreational_Ratio    77696
# Health_Impacts                       77696
# Urban_or_Rural                       77696
# dtype: int64

# %%
df['Age'] = df['Age'].astype(np.int16)
df['Age']
# Out:
# 0       14
# 1       11
# 2       18
# 3       15
# 4       12
#         ..
# 9707    17
# 9708    17
# 9709    16
# 9710    17
# 9711    15
# Name: Age, Length: 9712, dtype: int16

# %%
print("\nChecking for missing values using isnull():\n")
display(df.isnull())
display(df)
# Out:
# Checking for missing values using isnull():
#         Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0     False   False                     False           False
# 1     False   False                     False           False
# 2     False   False                     False           False
# 3     False   False                     False           False
# 4     False   False                     False           False
# ...     ...     ...                       ...             ...
# 9707  False   False                     False           False
# 9708  False   False                     False           False
# 9709  False   False                     False           False
# 9710  False   False                     False           False
# 9711  False   False                     False           False
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                          False                              False
# ...

# %%
print("\nCount of null values in each column:\n")
display(df.isnull().sum())
display(df)
# Out:
# Count of null values in each column:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# ...

# %%
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
print("\nCheck if any column contains null values:\n", )
df.isnull().any()
# Out:
# Check if any column contains null values:
# Age                                  False
# Gender                               False
# Avg_Daily_Screen_Time_hr             False
# Primary_Device                       False
# Exceeded_Recommended_Limit           False
# Educational_to_Recreational_Ratio    False
# Health_Impacts                        True
# Urban_or_Rural                       False
# dtype: bool

# %%
print("\nDropping rows with any missing values using dropna():\n")
x = df.dropna()
x
# Out:
# Dropping rows with any missing values using dropna():
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 4      12  Female                      5.89     Smartphone
# 5      14  Female                      4.88     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# ...

# %%
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
print("\nDropping columns with any missing values using dropna(axis=1):\n", )
y = df.dropna(axis=1)
# Out:
# Dropping columns with any missing values using dropna(axis=1):

# %%
display(df)
display(y)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
print("\nDropping duplicate rows using drop_duplicates():\n", )

df.drop_duplicates()
# Out:
# Dropping duplicate rows using drop_duplicates():
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# ...

# %%
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(df.isnull(), cbar=True, cmap='viridis', yticklabels=True)
plt.title('Heatmap of Missing Values')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
df.loc[2]
# Out:
# Age                                          18
# Gender                                   Female
# Avg_Daily_Screen_Time_hr                   3.73
# Primary_Device                               TV
# Exceeded_Recommended_Limit                 True
# Educational_to_Recreational_Ratio          0.32
# Health_Impacts                       Poor Sleep
# Urban_or_Rural                            Urban
# Name: 2, dtype: object

# %%
df.loc[[0,3]]
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 3   15  Female                      1.21         Laptop
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 3                       False                               0.39
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 3                     NaN          Urban

# %%
df.iloc[1,3]
# Out:
# 'Laptop'

# %%
df.iloc[[0, 2], [1, 3]]
# Out:
#    Gender Primary_Device
# 0    Male     Smartphone
# 2  Female             TV

# %%
plt.plot(df['Avg_Daily_Screen_Time_hr'], df['Primary_Device'], color='b')


# Add titles and labels
plt.title('  hist plot Avg_Daily_Screen_Time_hr of kids')
plt.xlabel(' Avg_Daily_Screen_Time_h')
plt.ylabel(' Primary_Device')

# Show the plot
plt.show()

# %%
df.head(10)
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
# 8   14    Male                      4.61         Laptop
# 9   18    Male                      3.24         Tablet
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# ...

# %%
data = df[['Age','Gender','Avg_Daily_Screen_Time_hr','Health_Impacts','Urban_or_Rural']]
data
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr                   Health_Impacts  \
# 0      14    Male                      3.99           Poor Sleep, Eye Strain
# 1      11  Female                      4.61                       Poor Sleep
# 2      18  Female                      3.73                       Poor Sleep
# 3      15  Female                      1.21                              NaN
# 4      12  Female                      5.89              Poor Sleep, Anxiety
# ...   ...     ...                       ...                              ...
# 9707   17    Male                      3.26                       Poor Sleep
# 9708   17  Female                      4.43                       Poor Sleep
# 9709   16    Male                      5.62  Poor Sleep, Eye Strain, Anxiety
# 9710   17    Male                      5.60                       Poor Sleep
# 9711   15  Female                      6.12                          Anxiety
#
#      Urban_or_Rural
# 0             Urban
# ...

# %%
plt.scatter(df['Avg_Daily_Screen_Time_hr'], df['Urban_or_Rural']) 
plt.title('Avg_Daily_Screen_Time_hr vs Urban_or_Rural')
plt.xlabel("Avg") 
plt.ylabel("Urban_or_Rural") 

plt.show()

# %%
plt.scatter(df['Age'], df['Avg_Daily_Screen_Time_hr'],alpha=0.3,edgecolors='g', linewidths=2)
plt.title('Age vs Avg_Daily_Screen_Time_hr ')
plt.xlabel("Age") # per match how many runs
plt.ylabel(" Avg_Daily_Screen_Time_hr ")

plt.show()

# %%
plt.scatter(df['Gender'], df['Avg_Daily_Screen_Time_hr'],alpha=0.5,edgecolors='none', linewidths=.9) # We can add one more column  using S
plt.title('Gender vs Avg_Daily_Screen_Time_hr ')
plt.xlabel("Gender") # per match how many runs
plt.ylabel("Avg_Daily_Screen_Time_hr  ")
plt.grid() 
plt.show()

# %%
plt.hist(df['Avg_Daily_Screen_Time_hr'])
plt.xlabel('Avg_Daily_Screen_Time_hr')
plt.ylabel('Frequency')
plt.title('Histogram of Avg_Daily_Screen_Time_hr')
# Out:
# Text(0.5, 1.0, 'Histogram of Avg_Daily_Screen_Time_hr')

# %%
plt.figure(figsize=(10, 6))
df['Health_Impacts']=df['Health_Impacts'].astype(str)
plt.bar(df['Health_Impacts'], df['Avg_Daily_Screen_Time_hr'], color='skyblue')
plt.xlabel('Health_Impacts')
plt.ylabel('Avg_Daily_Screen_Time_hr')
plt.title(' Bar plot of Avg_Daily_Screen_Time_hr vs Health_Impacts ')
plt.xticks(rotation=50,ha='right')
plt.yticks(rotation=50)
plt.show()

# %%
avg=df['Avg_Daily_Screen_Time_hr']
age=df['Age']
plt.figure(figsize=(10, 7))
plt.pie(avg, labels=age, autopct='%1.1f%%', startangle=10)
plt.title(' pie chartDistribution of Avg_Daily_Screen_Time_hr  by age')

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Avg_Daily_Screen_Time_hr'],  df['Age'])
plt.plot(df['Avg_Daily_Screen_Time_hr'],df['Gender'])

plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Two Features in a Single Plot')
plt.xticks(rotation=60)
plt.yticks(rotation=60)

plt.legend()
plt.show()
# Out:
# C:\Users\deksh\AppData\Local\Temp\ipykernel_32680\1918457265.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 10))
axes[0].bar(df['Avg_Daily_Screen_Time_hr'],df['Gender'])
axes[0].set_title('Gender')
axes[1].bar(df['Avg_Daily_Screen_Time_hr'],df["Age"])
axes[1].set_title('Age')
plt.title("subplots of avg_screen time by gender and age")


plt.show()

# %%
import seaborn as sns
import pandas as pd
import plotly.express as px
## https://github.com/plotly/datasets
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("STofkids.csv")

df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df.shape
# Out:
# (9712, 8)

# %%
df.	Primary_Device.unique(), df.Primary_Device.nunique()
# Out:
# (array(['Smartphone', 'Laptop', 'TV', 'Tablet'], dtype=object), 4)

# %%
df.Health_Impacts.unique(), df.Health_Impacts.nunique()
# Out:
# (array(['Poor Sleep, Eye Strain', 'Poor Sleep', nan, 'Poor Sleep, Anxiety',
#         'Poor Sleep, Obesity Risk', 'Eye Strain', 'Obesity Risk',
#         'Anxiety', 'Poor Sleep, Anxiety, Obesity Risk',
#         'Eye Strain, Obesity Risk', 'Eye Strain, Anxiety, Obesity Risk',
#         'Anxiety, Obesity Risk', 'Poor Sleep, Eye Strain, Obesity Risk',
#         'Poor Sleep, Eye Strain, Anxiety',
#         'Poor Sleep, Eye Strain, Anxiety, Obesity Risk',
#         'Eye Strain, Anxiety'], dtype=object),
#  15)

# %%
sns.lineplot(data=df, x='Age', y='Educational_to_Recreational_Ratio')
# Out:
# <Axes: xlabel='Age', ylabel='Educational_to_Recreational_Ratio'>

# %%
sns.lineplot(data=df, x='Primary_Device', y='Educational_to_Recreational_Ratio',ci=None)
# Out:
# C:\Users\deksh\AppData\Local\Temp\ipykernel_26680\2908423957.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='Primary_Device', y='Educational_to_Recreational_Ratio',ci=None)
# <Axes: xlabel='Primary_Device', ylabel='Educational_to_Recreational_Ratio'>

# %%
sns.lineplot(data=df, x='Age', y='Exceeded_Recommended_Limit',hue='Avg_Daily_Screen_Time_hr')
# Out:
# <Axes: xlabel='Age', ylabel='Exceeded_Recommended_Limit'>

# %%
sns.lineplot(data=df, x='Gender', y='Exceeded_Recommended_Limit',hue='Primary_Device')
# Out:
# <Axes: xlabel='Gender', ylabel='Exceeded_Recommended_Limit'>

# %%
sns.relplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', hue='Urban_or_Rural', size='Educational_to_Recreational_Ratio')
plt.title('Screen time of kids by Age')
plt.xlabel('Age')
plt.ylabel('Avg_Daily_Screen_Time_hr')
plt.show()

# %%
sns.relplot(data=df, x='Age', y='Educational_to_Recreational_Ratio', hue='Primary_Device', size='Avg_Daily_Screen_Time_hr')
plt.title('Screen time of kids by Age')
plt.xlabel('Age')
plt.ylabel('Educational_to_Recreational_Ratio')
plt.show()

# %%
sns.relplot(data=df, x='Age', y='Exceeded_Recommended_Limit', kind='line',col='Primary_Device')

# %%
sns.relplot(data=df, x='Age', y='Exceeded_Recommended_Limit', kind='line',col='Primary_Device',row='Gender')

# %%
df['Avg_Daily_Screen_Time_hr'].min(), df['Avg_Daily_Screen_Time_hr'].max()
# Out:
# (0.0, 13.89)

# %%
sns.histplot(data=df, x='Avg_Daily_Screen_Time_hr')
# Out:
# <Axes: xlabel='Avg_Daily_Screen_Time_hr', ylabel='Count'>

# %%
sns.displot(data=df, x='Avg_Daily_Screen_Time_hr', kind='hist')

# %%
sns.histplot(data=df, x='Avg_Daily_Screen_Time_hr', hue = 'Primary_Device',bins=15)
# Out:
# <Axes: xlabel='Avg_Daily_Screen_Time_hr', ylabel='Count'>

# %%
sns.histplot(data=df, x='Avg_Daily_Screen_Time_hr', hue = 'Exceeded_Recommended_Limit',bins=15)
# Out:
# <Axes: xlabel='Avg_Daily_Screen_Time_hr', ylabel='Count'>

# %%
sns.histplot(data=df, x='Exceeded_Recommended_Limit', hue = 'Primary_Device',bins=15)
# Out:
# <Axes: xlabel='Exceeded_Recommended_Limit', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='Age',hue='Primary_Device')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(data=df, x='Avg_Daily_Screen_Time_hr',col='Gender',kind='kde')

# %%
sns.displot(data=df, x='Avg_Daily_Screen_Time_hr',col='Primary_Device',kind='kde')

# %%
sns.displot(data=df, x='Avg_Daily_Screen_Time_hr',row='Primary_Device',col='Gender', kind='hist')

# %%
sns.displot(data=df, x='Educational_to_Recreational_Ratio', bins=8,col='Primary_Device',row='Gender',hue='Age')

# %%
sns.histplot(data=df, x='Educational_to_Recreational_Ratio', bins=8,hue='Gender', element='step')
# Out:
# <Axes: xlabel='Educational_to_Recreational_Ratio', ylabel='Count'>

# %%
sns.displot(data=df, x='Educational_to_Recreational_Ratio',row='Age',col='Gender', kind='kde')

# %%
sns.kdeplot(data=df, x="Avg_Daily_Screen_Time_hr")
# Out:
# <Axes: xlabel='Avg_Daily_Screen_Time_hr', ylabel='Density'>

# %%
sns.displot(data=df, x="Avg_Daily_Screen_Time_hr", kind="kde", hue='Age', fill=True)

# %%
sns.displot(data=df, x="Avg_Daily_Screen_Time_hr", kind="kde", hue='Gender', fill=True)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df, palette='pastel') #Set1 , Dark2
plt.title('Gender Distribution ')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\deksh\AppData\Local\Temp\ipykernel_11204\228773941.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel') #Set1 , Dark2

# %%
plt.figure(figsize=(6, 3))
sns.barplot(x='Age', y='Avg_Daily_Screen_Time_hr', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Avg_Daily_Screen_Time_hr'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Avg_Daily_Screen_Time_hr', data=df, ci=95)
plt.title('on an average/mean what is the  screen time of kids value every day')
plt.show()
# Out:
# C:\Users\deksh\AppData\Local\Temp\ipykernel_11204\1237651328.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Age', y='Avg_Daily_Screen_Time_hr', data=df, ci=95)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Educational_to_Recreational_Ratio',hue='Gender', data=df, palette='Dark2' ) # Vertical bar represents uncertinity/change/variability( error ) .
plt.title('on an average/mean what is the tota value every day') # Bar Height = Mean , Error bar represents CI = 95% .
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.pointplot(x='Primary_Device', y='Avg_Daily_Screen_Time_hr', data=df, estimator='mean')
plt.title('Point Plot Example')
plt.show()

# %%
sns.catplot(data=df, x="Exceeded_Recommended_Limit", y="Age", kind="point", col="Gender", row='Primary_Device')

# %%
sns.stripplot(data=df, x="Avg_Daily_Screen_Time_hr", y="Primary_Device")
# Out:
# <Axes: xlabel='Avg_Daily_Screen_Time_hr', ylabel='Primary_Device'>

# %%
sns.swarmplot(data=df, x="Primary_Device", y="Avg_Daily_Screen_Time_hr", hue='Primary_Device')
# Out:
# c:\Users\deksh\OneDrive\Desktop\Numpyproj\env\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 87.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\deksh\OneDrive\Desktop\Numpyproj\env\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\deksh\OneDrive\Desktop\Numpyproj\env\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 78.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\deksh\OneDrive\Desktop\Numpyproj\env\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 61.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(x='Health_Impacts', data=df)
plt.title('Box Plot of Health_Impacts ')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
sns.boxplot(x='Avg_Daily_Screen_Time_hr', data=df)
plt.title('Box Plot of total bill')

plt.show()

# %%
sns.boxplot(x='Educational_to_Recreational_Ratio', data=df, hue='Primary_Device')
# Out:
# <Axes: xlabel='Educational_to_Recreational_Ratio'>

# %%
sns.violinplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr',palette='tab10')
# Out:
# C:\Users\deksh\AppData\Local\Temp\ipykernel_32680\2231420219.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr',palette='tab10')
# <Axes: xlabel='Primary_Device', ylabel='Avg_Daily_Screen_Time_hr'>

# %%
data_St = df.pivot_table(index='Primary_Device', columns='Age', values='Avg_Daily_Screen_Time_hr',aggfunc='mean')

# %%
data_St
# Out:
# Age                   8         9         10        11        12        13  \
# Primary_Device
# Laptop               NaN       NaN       NaN  4.381256  4.523187  4.396023
# Smartphone      3.890515  3.892783  3.987265  4.543090  4.601027  4.471860
# TV              4.055493  3.974799  3.777155  4.493314  4.565325  4.652760
# Tablet          4.072963  3.925729  3.741143  4.555952  4.341154  4.524333
#
# Age                   14        15        16        17        18
# Primary_Device
# Laptop          4.379724  4.277831  4.648941  4.580221  4.515500
# Smartphone      4.620000  4.449534  4.486388  4.561061  4.518821
# TV              4.482069  4.546319  4.655989  4.487158  4.467216
# Tablet          4.319438  4.544706  4.459211  4.623488  4.483125

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_St,fmt='d', cmap='binary')
plt.title("Heatmap - kids of ages using Devices")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_St, annot=True, fmt='.2f', cmap='YlGnBu',linewidth=0.1)
plt.savefig("heatmap.png")
